# %%
import csv
import sys

from util import Node, StackFrontier, QueueFrontier

# %%
# Maps names to a set of corresponding person_ids
names = {}

# Maps person_ids to a dictionary of: name, birth, movies (a set of movie_ids)
people = {}

# Maps movie_ids to a dictionary of: title, year, stars (a set of person_ids)
movies = {}

# %%
def load_data(directory):
    """
    Load data from CSV files into memory.
    """
    # Load people
    with open(f"{directory}/people.csv", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            people[row["id"]] = {
                "name": row["name"],
                "birth": row["birth"],
                "movies": set()
            }
            if row["name"].lower() not in names:
                names[row["name"].lower()] = {row["id"]}
            else:
                names[row["name"].lower()].add(row["id"])
    
    # Load movies
    with open(f"{directory}/movies.csv", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            movies[row["id"]] = {
                "title": row["title"],
                "year": row["year"],
                "stars": set()
            }

# %%
def shortest_path(source, target):
    """
    Returns the shortest list of (movie_id, person_id) pairs
    that connect the source to the target.

    If no possible path, returns None.
    """

    # TODO
    raise NotImplementedError

# %%
def person_id_for_name(name):
    """
    Returns the IMDB id for a person's name,
    resolving ambiguities as needed.
    """
    person_ids = list(names.get(name.lower(), set()))
    if len(person_ids) == 0:
        return None
    elif len(person_ids) > 1:
        print(f"Which '{name}'?")
        for person_id in person_ids:
            person = people[person_id]
            name = person["name"]
            birth = person["birth"]
            print(f"ID: {person_id}, Name: {name}, Birth: {birth}")
        try:
            person_id = input("Intended Person ID: ")
            if person_id in person_ids:
                return person_id
        except ValueError:
            pass
        return None
    else:
        return person_ids[0]

# %%
def neighbors_for_person(person_id):
    """
    Returns (movie_id, person_id) pairs for people
    who starred with a given person.
    """
    movie_ids = people[person_id]["movies"]
    neighbors = set()
    for movie_id in movie_ids:
        for person_id in movies[movie_id]["stars"]:
            neighbors.add((movie_id, person_id))
    return neighbors

# %%
def main():
    #if len(sys.argv) > 2:
    #    sys.exit("Usage: python degrees.py [directory]")
    #directory = sys.argv[1] if len(sys.argv) == 2 else "large"

    directory= 'C:\Development\Python code and ML\CS50AI\degrees\degrees\large'

    # Load data from files into memory
    print("Loading data...")
    load_data(directory)
    print("Data loaded.")

    source = person_id_for_name(input("Name: "))
    if source is None:
        sys.exit("Person not found.")
    target = person_id_for_name(input("Name: "))
    if target is None:
        sys.exit("Person not found.")

    path = shortest_path(source, target)

    if path is None:
        print("Not connected.")
    else:
        degrees = len(path)
        print(f"{degrees} degrees of separation.")
        path = [(None, source)] + path
        for i in range(degrees):
            person1 = people[path[i][1]]["name"]
            person2 = people[path[i + 1][1]]["name"]
            movie = movies[path[i + 1][0]]["title"]
            print(f"{i + 1}: {person1} and {person2} starred in {movie}")

# %%
main()
# Out:
# Loading data...
# Data loaded.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-17-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-16-3c6a54ac1284> in main()
#      18         sys.exit("Person not found.")
#      19
# ---> 20     path = shortest_path(source, target)
#      21
#      22     if path is None:
#
# <ipython-input-6-0705ddf7d451> in shortest_path(source, target)
#       8
#       9     # TODO
# ---> 10     raise NotImplementedError
#
# NotImplementedError:

# %%
movies
# Out:
# {'15724': {'title': 'Dama de noche', 'year': '1993', 'stars': set()},
#  '23331': {'title': 'Pesn o geroyakh', 'year': '1983', 'stars': set()},
#  '31458': {'title': 'El huésped del sevillano',
#   'year': '1970',
#   'stars': set()},
#  '35423': {'title': 'Kate & Leopold', 'year': '2001', 'stars': set()},
#  '36606': {'title': 'Another Time, Another Place',
#   'year': '1983',
#   'stars': set()},
#  '39442': {'title': 'Habla, mudita', 'year': '1973', 'stars': set()},
#  '54724': {'title': 'I Eat Your Skin', 'year': '1971', 'stars': set()},
#  '56166': {'title': 'Lash of Lust', 'year': '1972', 'stars': set()},
#  '57461': {'title': 'La rosa de los vientos', 'year': '1983', 'stars': set()},
#  '58950': {'title': 'Auliban, the Seller of Rings',
#   'year': '1973',
#   'stars': set()},
#  '58994': {'title': "Bruce's Fingers", 'year': '1976', 'stars': set()},
#  '59680': {'title': "Satan's Harvest", 'year': '1970', 'stars': set()},
#  '59900': {'title': 'Wenn du groß bist, lieber Adam',
#   'year': '1990',
#   'stars': set()},
#  '60144': {'title': 'Aventura en las islas Cíes',
#   'year': '1972',
#   'stars': set()},
#  '60462': {'title': 'The Girls from Thunder Strip',
#   'year': '1970',
#   'stars': set()},
#  '60477': {'title': 'Gregorio and His Angel', 'year': '1970', 'stars': set()},
#  '60526': {'title': 'Huyendo del halcón', 'year': '1973', 'stars': set()},
#  '60551': {'title': 'Itt járt Mátyás király', 'year': '1973', 'stars': set()},
#  '60939': {'title': 'Santo contra los cazadores de cabezas',
#   'year': '1971',
#   'stars': set()},
#  '60951': {'title': 'A Scream in the Streets', 'year': '1973', 'stars': set()},
#  '60967': {'title': 'Una señora estupenda', 'year': '1970', 'stars': set()},
#  '61069': {'title': 'Taro the Dragon Boy', 'year': '1979', 'stars': set()},
#  '61151': {'title': 'The Lost Angel', 'year': '1971', 'stars': set()},
#  '61478': {'title': 'Chun huo', 'year': '1970', 'stars': set()},
#  '61494': {'title': 'Cauldron of Blood', 'year': '1970', 'stars': set()},
#  '61592': {'title': 'Doomsday Machine', 'year': '1972', 'stars': set()},
#  '61902': {'title': 'The Life of Mozart', 'year': '1970', 'stars': set()},
#  '62104': {'title': 'Fornicon', 'year': '1971', 'stars': set()},
#  '62105': {'title': 'Der Paukenspieler', 'year': '1971', 'stars': set()},
#  '62181': {'title': 'Rece do góry', 'year': '1981', 'stars': set()},
#  '62342': {'title': 'Tarzan and the Perils of Charity Jones',
#   'year': '1971',
#   'stars': set()},
#  '62359': {'title': 'The Bull Buster', 'year': '1973', 'stars': set()},
#  '62690': {'title': 'Awakening of the Beast', 'year': '1970', 'stars': set()},
#  '62696': {'title': 'Bakuchi-uchi: Nagaremono',
#   'year': '1970',
#   'stars': set()},
#  '62701': {'title': "Balsamus l'uomo di Satana",
#   'year': '1970',
#   'stars': set()},
#  '62730': {'title': 'The Big Snatch', 'year': '1971', 'stars': set()},
#  '62784': {'title': 'El certificado', 'year': '1970', 'stars': set()},
#  '62847': {'title': 'Daddy, Darling', 'year': '1970', 'stars': set()},
#  '62896': {'title': 'Divorcio a la andaluza', 'year': '1975', 'stars': set()},
#  '62936': {'title': 'Enter the Game of Death', 'year': '1978', 'stars': set()},
#  '62980': {'title': 'Fleshpot on 42nd Street', 'year': '1973', 'stars': set()},
#  '63018': {'title': 'Iron Dragon Strikes Back',
#   'year': '1979',
#   'stars': set()},
#  '63066': {'title': 'Hibotan bakuto: Oryû sanjô',
#   'year': '1970',
#   'stars': set()},
#  '63070': {'title': 'Story of a Girl Alone', 'year': '1971', 'stars': set()},
#  '63074': {'title': 'Hola... señor Dios', 'year': '1970', 'stars': set()},
#  '63132': {'title': 'Alien Terror', 'year': '1971', 'stars': set()},
#  '63137': {'title': 'The Invincible Six', 'year': '1970', 'stars': set()},
#  '63142': {'title': 'Isle of the Snake People',
#   'year': '1971',
#   'stars': set()},
#  '63244': {'title': 'Love Toy', 'year': '1971', 'stars': set()},
#  '63309': {'title': 'Misión cumplida', 'year': '1970', 'stars': set()},
#  '63334': {'title': "Nahtche V'Hageneral", 'year': '1972', 'stars': set()},
#  '63337': {'title': 'Al-nass wal Nil', 'year': '1972', 'stars': set()},
#  '63353': {'title': 'Nihon jokyo-den: tekka geisha',
#   'year': '1970',
#   'stars': set()},
#  '63498': {'title': 'Remolino de pasiones', 'year': '1970', 'stars': set()},
#  '63499': {'title': 'Ramparts of Clay', 'year': '1970', 'stars': set()},
#  '63550': {'title': "Satanis: The Devil's Mass",
#   'year': '1970',
#   'stars': set()},
#  '63552': {'title': 'Savage Intruder', 'year': '1970', 'stars': set()},
#  '63604': {'title': 'Shiruku hatto no ô-oyabun',
#   'year': '1970',
#   'stars': set()},
#  '63608': {'title': "Sinthia: The Devil's Doll",
#   'year': '1970',
#   'stars': set()},
#  '63666': {'title': 'Love, Emilia', 'year': '1970', 'stars': set()},
#  '63696': {'title': 'Tiger by the Tail', 'year': '1970', 'stars': set()},
#  '63751': {'title': 'The Howl', 'year': '1970', 'stars': set()},
#  '63846': {'title': 'Zorro, Rider of Vengeance',
#   'year': '1971',
#   'stars': set()},
#  '63860': {'title': 'The Last Day of the War', 'year': '1970', 'stars': set()},
#  '63982': {'title': 'El abominable hombre de la Costa del Sol',
#   'year': '1970',
#   'stars': set()},
#  '63987': {'title': 'Living on Credit', 'year': '1972', 'stars': set()},
#  '64004': {'title': 'All the Right Noises', 'year': '1971', 'stars': set()},
#  '64007': {'title': 'El alma se serena', 'year': '1970', 'stars': set()},
#  '64021': {'title': 'Love Is Gay, Love Is Sad',
#   'year': '1971',
#   'stars': set()},
#  '64031': {'title': "Don Franco e Don Ciccio nell'anno della contestazione",
#   'year': '1970',
#   'stars': set()},
#  '64038': {'title': 'The Land', 'year': '1970', 'stars': set()},
#  '64065': {'title': 'La banda de los tres crisantemos',
#   'year': '1970',
#   'stars': set()},
#  '64076': {'title': 'Before the Mountain Was Moved',
#   'year': '1970',
#   'stars': set()},
#  '64078': {'title': 'Les belles au bois dormantes',
#   'year': '1970',
#   'stars': set()},
#  '64083': {'title': "Der Bettenstudent oder Was mach' ich mit den Mädchen?",
#   'year': '1970',
#   'stars': set()},
#  '64105': {'title': 'The Ancines Woods', 'year': '1970', 'stars': set()},
#  '64106': {'title': 'Le Boucher', 'year': '1970', 'stars': set()},
#  '64111': {'title': 'Bronco Bullfrog', 'year': '1970', 'stars': set()},
#  '64121': {'title': 'Comrades', 'year': '1970', 'stars': set()},
#  '64126': {'title': 'French Intrigue', 'year': '1970', 'stars': set()},
#  '64140': {'title': 'Cateto a babor', 'year': '1970', 'stars': set()},
#  '64143': {'title': 'Siege of Terror', 'year': '1972', 'stars': set()},
#  '64144': {'title': 'The Circle', 'year': '1970', 'stars': set()},
#  '64150': {'title': 'La sfida dei MacKenna', 'year': '1970', 'stars': set()},
#  '64165': {'title': 'The Things of Life', 'year': '1970', 'stars': set()},
#  '64170': {'title': 'Her and She and Him', 'year': '1970', 'stars': set()},
#  '64171': {'title': 'The Bullet Machine', 'year': '1970', 'stars': set()},
#  '64177': {'title': 'Colossus: The Forbin Project',
#   'year': '1970',
#   'stars': set()},
#  '64182': {'title': 'Rimal min dhahab', 'year': '1971', 'stars': set()},
#  '64183': {'title': 'Con ella llegó el amor', 'year': '1970', 'stars': set()},
#  '64188': {'title': 'Crescendo', 'year': '1970', 'stars': set()},
#  '64190': {'title': 'Cristo 70', 'year': '1970', 'stars': set()},
#  '64191': {'title': 'El cronicón', 'year': '1970', 'stars': set()},
#  '64195': {'title': 'Cuatro desertores', 'year': '1970', 'stars': set()},
#  '64197': {'title': 'Cuori solitari', 'year': '1970', 'stars': set()},
#  '64204': {'title': 'Cómo casarse en 7 días', 'year': '1971', 'stars': set()},
#  '64225': {'title': 'Last Known Address', 'year': '1970', 'stars': set()},
#  '64250': {'title': 'Dornwittchen und Schneeröschen',
#   'year': '1970',
#   'stars': set()},
#  '64261': {'title': 'Dreams of Glass', 'year': '1970', 'stars': set()},
#  '64270': {'title': 'Dele color al difunto', 'year': '1970', 'stars': set()},
#  '64273': {'title': 'And God Said to Cain', 'year': '1970', 'stars': set()},
#  '64279': {'title': 'A Crazy Night', 'year': '1970', 'stars': set()},
#  '64283': {'title': 'An Elephant Called Slowly',
#   'year': '1970',
#   'stars': set()},
#  '64285': {'title': 'The Wild Child', 'year': '1970', 'stars': set()},
#  '64294': {'title': 'La horse', 'year': '1970', 'stars': set()},
#  '64321': {'title': 'The Female Bunch', 'year': '1971', 'stars': set()},
#  '64341': {'title': 'Fortunata and Jacinta', 'year': '1970', 'stars': set()},
#  '64343': {'title': 'Four Rode Out', 'year': '1970', 'stars': set()},
#  '64359': {'title': 'The Gamblers', 'year': '1970', 'stars': set()},
#  '64362': {'title': 'Las gatas tienen frío', 'year': '1970', 'stars': set()},
#  '64372': {'title': 'Black Jack', 'year': '1972', 'stars': set()},
#  '64377': {'title': 'Golpe de mano (Explosión)',
#   'year': '1970',
#   'stars': set()},
#  '64385': {'title': 'Shine, Shine, My Star', 'year': '1970', 'stars': set()},
#  '64386': {'title': 'The Fifth Day of Peace', 'year': '1970', 'stars': set()},
#  '64388': {'title': 'El gran crucero', 'year': '1970', 'stars': set()},
#  '64411': {'title': 'Heintje - Einmal wird die Sonne wieder scheinen',
#   'year': '1970',
#   'stars': set()},
#  '64413': {'title': 'Helena y Fernanda', 'year': '1970', 'stars': set()},
#  '64420': {'title': 'The Inheritors', 'year': '1970', 'stars': set()},
#  '64423': {'title': 'Happy He Who Like Ulysses',
#   'year': '1970',
#   'stars': set()},
#  '64430': {'title': 'Hildur and the Magician', 'year': '1971', 'stars': set()},
#  '64432': {'title': 'How to Play the Seduction Game',
#   'year': '1970',
#   'stars': set()},
#  '64437': {'title': 'The Honeymoon Killers', 'year': '1970', 'stars': set()},
#  '64450': {'title': 'How to Succeed with Sex', 'year': '1970', 'stars': set()},
#  '64451': {'title': 'A Touch of Zen', 'year': '1971', 'stars': set()},
#  '64465': {'title': 'Ice', 'year': '1970', 'stars': set()},
#  '64484': {'title': 'The Indiscreet One', 'year': '1970', 'stars': set()},
#  '64494': {'title': 'Eugenie', 'year': '1970', 'stars': set()},
#  '64510': {'title': 'Jenny', 'year': '1970', 'stars': set()},
#  '64522': {'title': 'Mr. and Mrs. Juan Lamaglia',
#   'year': '1970',
#   'stars': set()},
#  '64535': {'title': 'The Kashmiri Run', 'year': '1970', 'stars': set()},
#  '64546': {'title': 'Witchhammer', 'year': '1970', 'stars': set()},
#  '64549': {'title': 'Komm nach Wien, ich zeig dir was!',
#   'year': '1970',
#   'stars': set()},
#  '64553': {'title': 'King Lear', 'year': '1970', 'stars': set()},
#  '64554': {'title': 'King of the Reindeer', 'year': '1970', 'stars': set()},
#  '64574': {'title': 'The Last of the Mobile Hot Shots',
#   'year': '1970',
#   'stars': set()},
#  '64582': {'title': 'Der Leone Have Sept Cabeças',
#   'year': '1970',
#   'stars': set()},
#  '64586': {'title': 'Juan Pedro the Scyther', 'year': '1970', 'stars': set()},
#  '64592': {'title': 'Lisa dagli occhi blu', 'year': '1970', 'stars': set()},
#  '64593': {'title': "The Virgin's Bed", 'year': '1970', 'stars': set()},
#  '64594': {'title': 'Little Jungle Boy', 'year': '1971', 'stars': set()},
#  '64598': {'title': 'London Affair', 'year': '1970', 'stars': set()},
#  '64604': {'title': 'Love Me... Please!', 'year': '1972', 'stars': set()},
#  '64607': {'title': 'Love Is a Splendid Illusion',
#   'year': '1970',
#   'stars': set()},
#  '64614': {'title': 'Rose Spot', 'year': '1970', 'stars': set()},
#  '64624': {'title': 'Maid in Sweden', 'year': '1971', 'stars': set()},
#  '64625': {'title': 'Maidstone', 'year': '1970', 'stars': set()},
#  '64628': {'title': 'Mama vyshla zamuzh', 'year': '1970', 'stars': set()},
#  '64633': {'title': 'Awkward Hands', 'year': '1970', 'stars': set()},
#  '64649': {'title': 'The McMasters', 'year': '1970', 'stars': set()},
#  '64656': {'title': 'El mejor del mundo', 'year': '1970', 'stars': set()},
#  '64659': {'title': 'El mesón del gitano', 'year': '1970', 'stars': set()},
#  '64687': {'title': 'Assignment Terror', 'year': '1970', 'stars': set()},
#  '64702': {'title': 'Moy papa - kapitan', 'year': '1970', 'stars': set()},
#  '64704': {'title': 'Girly', 'year': '1970', 'stars': set()},
#  '64706': {'title': "My Girlfriend's Wedding", 'year': '1973', 'stars': set()},
#  '64711': {'title': 'Männer sind zum Lieben da',
#   'year': '1970',
#   'stars': set()},
#  '64712': {'title': 'The Moderate Doctor', 'year': '1971', 'stars': set()},
#  '64727': {'title': 'The Bloody Judge', 'year': '1970', 'stars': set()},
#  '64741': {'title': 'Nu xia mai ren tou', 'year': '1970', 'stars': set()},
#  '64742': {'title': 'Los nuestros', 'year': '1970', 'stars': set()},
#  '64746': {'title': 'OSS 117 prend des vacances',
#   'year': '1970',
#   'stars': set()},
#  '64751': {'title': 'Odvázná slecna', 'year': '1970', 'stars': set()},
#  '64753': {'title': 'Sweet Kisses and Languid Caresses',
#   'year': '1970',
#   'stars': set()},
#  '64761': {'title': 'One Brief Summer', 'year': '1971', 'stars': set()},
#  '64768': {'title': 'Ore di terrore', 'year': '1971', 'stars': set()},
#  '64772': {'title': 'The Sensual Male', 'year': '1970', 'stars': set()},
#  '64773': {'title': 'Other Voices', 'year': '1970', 'stars': set()},
#  '64774': {'title': 'Eyes Do Not Want to Close at All Times, or, Perhaps One Day Rome Will Allow Herself to Choose in Her Turn',
#   'year': '1970',
#   'stars': set()},
#  '64779': {'title': 'The Bear and the Doll', 'year': '1970', 'stars': set()},
#  '64781': {'title': 'Fruit of Paradise', 'year': '1970', 'stars': set()},
#  '64787': {'title': 'A Quiet Place to Kill', 'year': '1970', 'stars': set()},
#  '64788': {'title': 'Paraíso', 'year': '1970', 'stars': set()},
#  '64791': {'title': 'Rider on the Rain', 'year': '1970', 'stars': set()},
#  '64796': {'title': 'Only the Cool', 'year': '1970', 'stars': set()},
#  '64803': {'title': 'Pesn o Manshuk', 'year': '1974', 'stars': set()},
#  '64804': {'title': 'Le petit bougnat', 'year': '1970', 'stars': set()},
#  '64805': {'title': 'The People and Their Guns',
#   'year': '1970',
#   'stars': set()},
#  '64806': {'title': 'The Phantom Tollbooth', 'year': '1970', 'stars': set()},
#  '64820': {'title': 'The Plot Against Harry', 'year': '1989', 'stars': set()},
#  '64821': {'title': 'On the Trail of Blood', 'year': '1970', 'stars': set()},
#  '64822': {'title': 'El pocho', 'year': '1970', 'stars': set()},
#  '64831': {'title': 'Posledniye kanikuly', 'year': '1970', 'stars': set()},
#  '64832': {'title': 'Posol Sovetskogo Soyuza', 'year': '1970', 'stars': set()},
#  '64836': {'title': 'Prana', 'year': '1970', 'stars': set()},
#  '64839': {'title': 'Crime and Punishment', 'year': '1970', 'stars': set()},
#  '64843': {'title': 'Case for a Rookie Hangman',
#   'year': '1970',
#   'stars': set()},
#  '64847': {'title': 'Prologue', 'year': '1970', 'stars': set()},
#  '64848': {'title': 'A Promise of Bed', 'year': '1970', 'stars': set()},
#  '64849': {'title': 'La provocation', 'year': '1970', 'stars': set()},
#  '64858': {'title': 'Pyat dney otdykha', 'year': '1970', 'stars': set()},
#  '64863': {'title': 'Quelé do Pajeú', 'year': '1970', 'stars': set()},
#  '64864': {'title': 'El quelite', 'year': '1970', 'stars': set()},
#  '64881': {'title': 'The Reckoning', 'year': '1970', 'stars': set()},
#  '64887': {'title': 'Resende', 'year': '1970', 'stars': set()},
#  '64900': {'title': 'Robinson Crusoe', 'year': '1970', 'stars': set()},
#  '64902': {'title': 'The Blood Rose', 'year': '1970', 'stars': set()},
#  '64904': {'title': 'Hatchet for the Honeymoon',
#   'year': '1970',
#   'stars': set()},
#  '64905': {'title': 'Rote Sonne', 'year': '1970', 'stars': set()},
#  '64930': {'title': 'Santo vs. Blue Demon in Atlantis',
#   'year': '1970',
#   'stars': set()},
#  '64931': {'title': 'The Knight of the Sword', 'year': '1970', 'stars': set()},
#  '64932': {'title': 'Santo and Blue Demon Against the Monsters',
#   'year': '1970',
#   'stars': set()},
#  '64933': {'title': 'Land of the Dead', 'year': '1970', 'stars': set()},
#  '64945': {'title': 'Schwarzer Nerz auf zarter Haut',
#   'year': '1970',
#   'stars': set()},
#  '64949': {'title': 'Scream and Scream Again', 'year': '1970', 'stars': set()},
#  '64953': {'title': 'Secret Intentions', 'year': '1970', 'stars': set()},
#  '64956': {'title': 'Segundo Festival de Mortadelo y Filemón, agencia de información',
#   'year': '1970',
#   'stars': set()},
#  '64963': {'title': 'The Set', 'year': '1970', 'stars': set()},
#  '64964': {'title': 'Overrun!', 'year': '1970', 'stars': set()},
#  '64967': {'title': 'Sex-Business - Made in Pasing',
#   'year': '1970',
#   'stars': set()},
#  '64980': {'title': 'Siempre hay una primera vez',
#   'year': '1971',
#   'stars': set()},
#  '64994': {'title': 'Larks on a String', 'year': '1990', 'stars': set()},
#  '65005': {'title': 'Oso yparhei erotas', 'year': '1970', 'stars': set()},
#  '65012': {'title': "Some Will, Some Won't", 'year': '1970', 'stars': set()},
#  '65013': {'title': "Some Won't Go", 'year': '1970', 'stars': set()},
#  '65034': {'title': 'Staryy dom', 'year': '1970', 'stars': set()},
#  '65039': {'title': "Una storia d'amore", 'year': '1970', 'stars': set()},
#  '65040': {'title': 'Strange Holiday', 'year': '1970', 'stars': set()},
#  '65050': {'title': 'The Super Fight', 'year': '1970', 'stars': set()},
#  '65073': {'title': 'Taste the Blood of Dracula',
#   'year': '1970',
#   'stars': set()},
#  '65080': {'title': 'The Heist', 'year': '1970', 'stars': set()},
#  '65084': {'title': 'The Witnesses', 'year': '1971', 'stars': set()},
#  '65117': {'title': 'Adrift', 'year': '1971', 'stars': set()},
#  '65127': {'title': 'Tchaikovsky', 'year': '1970', 'stars': set()},
#  '65128': {'title': 'Belated Flowers', 'year': '1970', 'stars': set()},
#  '65134': {'title': 'Two Mules for Sister Sara',
#   'year': '1970',
#   'stars': set()},
#  '65139': {'title': 'Történelmi magánügyek', 'year': '1970', 'stars': set()},
#  '65140': {'title': 'U ozera', 'year': '1970', 'stars': set()},
#  '65143': {'title': 'The Bird with the Crystal Plumage',
#   'year': '1970',
#   'stars': set()},
#  '65147': {'title': 'Un, dos, tres... al escondite inglés',
#   'year': '1970',
#   'stars': set()},
#  '65161': {'title': 'La vacanza', 'year': '1971', 'stars': set()},
#  '65162': {'title': 'Vacío en el alma', 'year': '1971', 'stars': set()},
#  '65167': {'title': 'Vamos por la parejita', 'year': '1971', 'stars': set()},
#  '65168': {'title': 'The Nude Vampire', 'year': '1970', 'stars': set()},
#  '65171': {'title': 'La venganza de las mujeres vampiro',
#   'year': '1970',
#   'stars': set()},
#  '65173': {'title': "Le Vent d'Est", 'year': '1970', 'stars': set()},
#  '65174': {'title': 'Verano 70', 'year': '1970', 'stars': set()},
#  '65188': {'title': 'Vojtech, receny sirotek', 'year': '1990', 'stars': set()},
#  '65189': {'title': 'Von Haut zu Haut', 'year': '1971', 'stars': set()},
#  '65192': {'title': 'The Voyeur', 'year': '1970', 'stars': set()},
#  '65210': {'title': 'Whirlpool', 'year': '1970', 'stars': set()},
#  '65213': {'title': 'Wilbur and the Baby Factory',
#   'year': '1970',
#   'stars': set()},
#  '65221': {'title': 'Wolfshead: The Legend of Robin Hood',
#   'year': '1976',
#   'stars': set()},
#  '65222': {'title': 'Women and Bloody Terror', 'year': '1970', 'stars': set()},
#  '65227': {'title': 'Sex Freedom in Germany', 'year': '1970', 'stars': set()},
#  '65235': {'title': 'I Killed Einstein, Gentlemen',
#   'year': '1970',
#   'stars': set()},
#  '65248': {'title': 'Zorro the Invincible', 'year': '1971', 'stars': set()},
#  '65251': {'title': '¡¡Se armó el belén!!', 'year': '1970', 'stars': set()},
#  '65253': {'title': '¿Es usted mi padre?', 'year': '1971', 'stars': set()},
#  '65254': {'title': 'Por qué pecamos a los cuarenta',
#   'year': '1970',
#   'stars': set()},
#  '65256': {'title': '¿Quién soy yo?', 'year': '1970', 'stars': set()},
#  '65259': {'title': 'El águila descalza', 'year': '1971', 'stars': set()},
#  '65265': {'title': 'The Stud', 'year': '1970', 'stars': set()},
#  '65331': {'title': 'You Are a Widow, Sir!', 'year': '1971', 'stars': set()},
#  '65359': {'title': 'M comme Mathieu', 'year': '1973', 'stars': set()},
#  '65360': {'title': '...tick... tick... tick...',
#   'year': '1970',
#   'stars': set()},
#  '65363': {'title': 'The Daughter: I, a Woman Part III',
#   'year': '1970',
#   'stars': set()},
#  '65365': {'title': 'Abarten der körperlichen Liebe',
#   'year': '1970',
#   'stars': set()},
#  '65366': {'title': 'Abel, Your Brother', 'year': '1970', 'stars': set()},
#  '65367': {'title': "Dig Your Grave Friend... Sabata's Coming",
#   'year': '1971',
#   'stars': set()},
#  '65370': {'title': 'Act of the Heart', 'year': '1970', 'stars': set()},
#  '65371': {'title': 'Adam at Six A.M.', 'year': '1970', 'stars': set()},
#  '65372': {'title': "Adam's Woman", 'year': '1970', 'stars': set()},
#  '65373': {'title': '20,000 dólares por un cadáver',
#   'year': '1971',
#   'stars': set()},
#  '65374': {'title': 'The Adventurers', 'year': '1970', 'stars': set()},
#  '65375': {'title': 'The Adventures of Gerard',
#   'year': '1970',
#   'stars': set()},
#  '65376': {'title': 'Mr. Gullible', 'year': '1970', 'stars': set()},
#  '65377': {'title': 'Airport', 'year': '1970', 'stars': set()},
#  '65378': {'title': 'May Morning', 'year': '1970', 'stars': set()},
#  '65379': {'title': 'Album polski', 'year': '1970', 'stars': set()},
#  '65380': {'title': 'Alex in Wonderland', 'year': '1970', 'stars': set()},
#  '65384': {'title': 'All the Way Up', 'year': '1970', 'stars': set()},
#  '65385': {'title': 'The Wedding Ring', 'year': '1970', 'stars': set()},
#  '65388': {'title': 'Am Ama am Amazonas', 'year': '1970', 'stars': set()},
#  '65390': {'title': 'The Amazing Transplant', 'year': '1970', 'stars': set()},
#  '65391': {'title': 'The American Soldier', 'year': '1970', 'stars': set()},
#  '65392': {'title': 'Bucharest Memories', 'year': '1970', 'stars': set()},
#  '65393': {'title': 'The Friends', 'year': '1971', 'stars': set()},
#  '65394': {'title': "L'amore coniugale", 'year': '1970', 'stars': set()},
#  '65395': {'title': 'Amore formula 2', 'year': '1970', 'stars': set()},
#  '65396': {'title': 'Reconstruction', 'year': '1970', 'stars': set()},
#  '65398': {'title': 'And Soon the Darkness', 'year': '1970', 'stars': set()},
#  '65400': {'title': 'The Angel Levine', 'year': '1970', 'stars': set()},
#  '65401': {'title': 'Angel Unchained', 'year': '1970', 'stars': set()},
#  '65402': {'title': 'Angelica: The Young Vixen',
#   'year': '1974',
#   'stars': set()},
#  '65405': {'title': 'Angels Die Hard', 'year': '1970', 'stars': set()},
#  '65406': {'title': 'Million Dollar Eel', 'year': '1971', 'stars': set()},
#  '65407': {'title': 'The Animals', 'year': '1970', 'stars': set()},
#  '65408': {'title': 'The Anonymous Venetian', 'year': '1970', 'stars': set()},
#  '65410': {'title': 'Aoom', 'year': '1970', 'stars': set()},
#  '65411': {'title': 'Apa ca un bivol negru', 'year': '1970', 'stars': set()},
#  '65412': {'title': 'An Apple a Day', 'year': '1970', 'stars': set()},
#  '65413': {'title': 'The Night of the Assassin',
#   'year': '1970',
#   'stars': set()},
#  '65414': {'title': "Appunti per un romanzo dell'immondezza",
#   'year': '1970',
#   'stars': set()},
#  '65417': {'title': 'Days and Nights in the Forest',
#   'year': '1970',
#   'stars': set()},
#  '65418': {'title': 'La araucana', 'year': '1971', 'stars': set()},
#  '65419': {'title': 'Face', 'year': '1970', 'stars': set()},
#  '65420': {'title': 'Long Live Robin Hood', 'year': '1971', 'stars': set()},
#  '65421': {'title': 'The Aristocats', 'year': '1970', 'stars': set()},
#  '65422': {'title': 'Arizona Lets Fly and Kill Everybody',
#   'year': '1970',
#   'stars': set()},
#  '65424': {'title': 'Sweet Kill', 'year': '1972', 'stars': set()},
#  '65425': {'title': 'Sabata the Killer', 'year': '1970', 'stars': set()},
#  '65427': {'title': 'Aru heishi no kake', 'year': '1970', 'stars': set()},
#  '65429': {'title': 'Asediul', 'year': '1971', 'stars': set()},
#  '65430': {'title': 'A Very Crazy Asylum', 'year': '1970', 'stars': set()},
#  '65432': {'title': 'El astronauta', 'year': '1970', 'stars': set()},
#  '65433': {'title': 'Atakku no. 1: Namida no kaiten reshîbu',
#   'year': '1970',
#   'stars': set()},
#  '65434': {'title': 'Atakku no. 1', 'year': '1970', 'stars': set()},
#  '65435': {'title': 'Atakku no. 1: Namida no sekai senshuken',
#   'year': '1970',
#   'stars': set()},
#  '65436': {'title': 'Even Dwarfs Started Small',
#   'year': '1970',
#   'stars': set()},
#  '65437': {'title': 'Aus unserer Zeit', 'year': '1970', 'stars': set()},
#  '65438': {'title': 'Ausweglos. Aussagen über einen Lebenslauf',
#   'year': '1970',
#   'stars': set()},
#  '65439': {'title': 'The Confession', 'year': '1970', 'stars': set()},
#  '65441': {'title': 'The Baby Maker', 'year': '1970', 'stars': set()},
#  '65443': {'title': 'Bakumatsu', 'year': '1970', 'stars': set()},
#  '65445': {'title': 'The Ball of Count Orgel', 'year': '1970', 'stars': set()},
#  '65446': {'title': 'The Ballad of Cable Hogue',
#   'year': '1970',
#   'stars': set()},
#  '65447': {'title': 'Ballada o Beringe i ego druzyakh',
#   'year': '1971',
#   'stars': set()},
#  '65448': {'title': 'A Baltic Tragedy', 'year': '1970', 'stars': set()},
#  '65450': {'title': 'Vengeance', 'year': '1970', 'stars': set()},
#  '65451': {'title': 'Barquero', 'year': '1970', 'stars': set()},
#  '65452': {'title': 'Bartleby', 'year': '1970', 'stars': set()},
#  '65453': {'title': 'Cuba: Battle of the 10,000,000',
#   'year': '1971',
#   'stars': set()},
#  '65454': {'title': 'The Boat on the Grass', 'year': '1971', 'stars': set()},
#  '65456': {'title': 'Beast of Blood', 'year': '1970', 'stars': set()},
#  '65457': {'title': 'Beg', 'year': '1971', 'stars': set()},
#  '65458': {'title': 'The Amorous Adventures of a Young Postman',
#   'year': '1970',
#   'stars': set()},
#  '65459': {'title': 'The Beloved', 'year': '1971', 'stars': set()},
#  '65460': {'title': 'The Beast', 'year': '1970', 'stars': set()},
#  '65462': {'title': 'Beneath the Planet of the Apes',
#   'year': '1970',
#   'stars': set()},
#  '65465': {'title': 'Die Bettwurst', 'year': '1971', 'stars': set()},
#  '65466': {'title': 'Beyond the Valley of the Dolls',
#   'year': '1970',
#   'stars': set()},
#  '65467': {'title': 'Bhai-Bhai', 'year': '1970', 'stars': set()},
#  '65470': {'title': 'Bigfoot', 'year': '1970', 'stars': set()},
#  '65473': {'title': 'Birth of the Japanese Islands',
#   'year': '1970',
#   'stars': set()},
#  '65474': {'title': 'Black Angels', 'year': '1970', 'stars': set()},
#  '65475': {'title': 'Black Pearl', 'year': '1970', 'stars': set()},
#  '65476': {'title': "Blondie's Number One", 'year': '1971', 'stars': set()},
#  '65478': {'title': 'Blood Mania', 'year': '1970', 'stars': set()},
#  '65479': {'title': 'Blood of the Iron Maiden',
#   'year': '1970',
#   'stars': set()},
#  '65480': {'title': 'Bloodthirsty Butchers', 'year': '1970', 'stars': set()},
#  '65481': {'title': 'Bloody Mama', 'year': '1970', 'stars': set()},
#  '65482': {'title': 'The Boatniks', 'year': '1970', 'stars': set()},
#  '65483': {'title': 'The Body Beneath', 'year': '1970', 'stars': set()},
#  '65484': {'title': 'Bombay Talkie', 'year': '1970', 'stars': set()},
#  '65485': {'title': "Bongo Wolf's Revenge", 'year': '1970', 'stars': set()},
#  '65486': {'title': 'Borsalino', 'year': '1970', 'stars': set()},
#  '65488': {'title': 'The Boys in the Band', 'year': '1970', 'stars': set()},
#  '65489': {'title': 'Brancaleone at the Crusades',
#   'year': '1970',
#   'stars': set()},
#  '65491': {'title': 'Mark of the Devil', 'year': '1970', 'stars': set()},
#  '65492': {'title': 'Brewster McCloud', 'year': '1970', 'stars': set()},
#  '65493': {'title': 'The Bridge in the Jungle',
#   'year': '1970',
#   'stars': set()},
#  '65494': {'title': 'See You at Mao', 'year': '1970', 'stars': set()},
#  '65495': {'title': 'Brothers Five', 'year': '1970', 'stars': set()},
#  '65497': {'title': 'Bruno der Schwarze - Es blies ein Jäger wohl in sein Horn',
#   'year': '1971',
#   'stars': set()},
#  '65498': {'title': 'Brother Carl', 'year': '1971', 'stars': set()},
#  '65499': {'title': 'Have a Good Funeral, My Friend... Sartana Will Pay',
#   'year': '1970',
#   'stars': set()},
#  '65500': {'title': 'El bueno para nada', 'year': '1973', 'stars': set()},
#  '65501': {'title': 'A Bullet for Pretty Boy', 'year': '1970', 'stars': set()},
#  '65503': {'title': 'The Scandalous Adventures of Buraikan',
#   'year': '1970',
#   'stars': set()},
#  '65506': {'title': 'Popsy Pop', 'year': '1971', 'stars': set()},
#  '65509': {'title': "Sartana's Here... Trade Your Pistol for a Coffin",
#   'year': '1970',
#   'stars': set()},
#  '65511': {'title': 'C.C. & Company', 'year': '1970', 'stars': set()},
#  '65512': {'title': 'Cutting Heads', 'year': '1970', 'stars': set()},
#  '65514': {'title': 'Cactus in the Snow', 'year': '1971', 'stars': set()},
#  '65515': {'title': 'Qui?', 'year': '1970', 'stars': set()},
#  '65516': {'title': 'La califfa', 'year': '1970', 'stars': set()},
#  '65517': {'title': 'Viva Cangaceiro', 'year': '1970', 'stars': set()},
#  '65518': {'title': 'The Year of the Cannibals',
#   'year': '1970',
#   'stars': set()},
#  '65520': {'title': 'Cannon for Cordoba', 'year': '1970', 'stars': set()},
#  '65521': {'title': 'Give Her the Moon', 'year': '1970', 'stars': set()},
#  '65524': {'title': 'Carry on Loving', 'year': '1970', 'stars': set()},
#  '65525': {'title': 'Carry on Up the Jungle', 'year': '1970', 'stars': set()},
#  '65526': {'title': 'La casa de los Martínez', 'year': '1971', 'stars': set()},
#  '65527': {'title': 'A Pocketful of Chestnuts',
#   'year': '1970',
#   'stars': set()},
#  '65528': {'title': 'Catch-22', 'year': '1970', 'stars': set()},
#  '65529': {'title': 'Cerca di capirmi', 'year': '1970', 'stars': set()},
#  '65530': {'title': 'Le cercle des passions', 'year': '1983', 'stars': set()},
#  '65531': {'title': 'Le Cercle Rouge', 'year': '1970', 'stars': set()},
#  '65532': {'title': 'A Chafarica', 'year': '1970', 'stars': set()},
#  '65533': {'title': 'The Seagull', 'year': '1972', 'stars': set()},
#  '65535': {'title': 'Champagne Rose är död', 'year': '1970', 'stars': set()},
#  '65536': {'title': 'The Mushroom', 'year': '1970', 'stars': set()},
#  '65538': {'title': 'Chanoc contra el tigre y el vampiro',
#   'year': '1972',
#   'stars': set()},
#  '65539': {'title': 'Chanoc en las garras de las fieras',
#   'year': '1970',
#   'stars': set()},
#  '65541': {'title': 'Chesty: A Tribute to a Legend',
#   'year': '1976',
#   'stars': set()},
#  '65542': {'title': 'The Cheyenne Social Club',
#   'year': '1970',
#   'stars': set()},
#  '65543': {'title': 'Chi-zome no daimon', 'year': '1970', 'stars': set()},
#  '65544': {'title': 'Little Remi and Famous Dog Capi',
#   'year': '1970',
#   'stars': set()},
#  '65545': {'title': 'Canticle', 'year': '1970', 'stars': set()},
#  '65547': {'title': 'Chisum', 'year': '1970', 'stars': set()},
#  '65548': {'title': 'Chrezvychainyy komissar', 'year': '1970', 'stars': set()},
#  '65549': {'title': 'The Christine Jorgensen Story',
#   'year': '1970',
#   'stars': set()},
#  '65550': {'title': 'The Unholy Four', 'year': '1970', 'stars': set()},
#  '65551': {'title': 'Ciao, Federico!', 'year': '1970', 'stars': set()},
#  '65552': {'title': 'Os cinco Avisos de Satanás',
#   'year': '1970',
#   'stars': set()},
#  '65553': {'title': 'Five Dolls for an August Moon',
#   'year': '1970',
#   'stars': set()},
#  '65554': {'title': 'Le cinéma de papa', 'year': '1971', 'stars': set()},
#  '65555': {'title': 'Violent City', 'year': '1970', 'stars': set()},
#  '65557': {'title': 'The Class Reunion', 'year': '1972', 'stars': set()},
#  '65560': {'title': 'Cockeyed Cowboys of Calico County',
#   'year': '1970',
#   'stars': set()},
#  '65561': {'title': 'The Mad Heart', 'year': '1970', 'stars': set()},
#  '65562': {'title': 'Long mu xiang', 'year': '1970', 'stars': set()},
#  '65563': {'title': 'The Penal Colony', 'year': '1970', 'stars': set()},
#  '65565': {'title': 'Countdown to Vengeance', 'year': '1971', 'stars': set()},
#  '65567': {'title': 'Con la música a otra parte',
#   'year': '1974',
#   'stars': set()},
#  '65568': {'title': 'The Weekend Murders', 'year': '1970', 'stars': set()},
#  '65569': {'title': 'Count Dracula', 'year': '1970', 'stars': set()},
#  '65570': {'title': 'El Condor', 'year': '1970', 'stars': set()},
#  '65571': {'title': 'The Conformist', 'year': '1970', 'stars': set()},
#  '65572': {'title': 'When Heroes Die', 'year': '1970', 'stars': set()},
#  '65573': {'title': "Let's Have a Riot", 'year': '1970', 'stars': set()},
#  '65574': {'title': 'Bust Out', 'year': '1973', 'stars': set()},
#  '65575': {'title': 'Cool It, Carol!', 'year': '1970', 'stars': set()},
#  '65577': {'title': 'Le coppie', 'year': '1970', 'stars': set()},
#  '65578': {'title': 'Coqueluche', 'year': '1970', 'stars': set()},
#  '65579': {'title': 'Cotton Comes to Harlem', 'year': '1970', 'stars': set()},
#  '65580': {'title': 'Countess Dracula', 'year': '1971', 'stars': set()},
#  '65581': {'title': 'Brotherly Love', 'year': '1970', 'stars': set()},
#  '65582': {'title': 'Cover Me Babe', 'year': '1970', 'stars': set()},
#  '65583': {'title': 'Covilhã - Cidade da Serra e do Vale',
#   'year': '1970',
#   'stars': set()},
#  '65584': {'title': 'Safety Catch', 'year': '1970', 'stars': set()},
#  '65585': {'title': 'Crates', 'year': '1970', 'stars': set()},
#  '65586': {'title': 'Secret Life of a Schoolgirl Wife',
#   'year': '1971',
#   'stars': set()},
#  '65587': {'title': 'Creedence Clearwater Revival Live in London',
#   'year': '1970',
#   'stars': set()},
#  '65588': {'title': 'Cleopatra', 'year': '1970', 'stars': set()},
#  '65589': {'title': 'Cry of the Cormoran', 'year': '1971', 'stars': set()},
#  '65590': {'title': 'Crimen imperfecto', 'year': '1970', 'stars': set()},
#  '65591': {'title': 'Crimes of the Future', 'year': '1970', 'stars': set()},
#  '65592': {'title': 'Crisis mortal (La sombra del girasol)',
#   'year': '1970',
#   'stars': set()},
#  '65593': {'title': 'Cromwell', 'year': '1970', 'stars': set()},
#  '65595': {'title': 'Crucible of Horror', 'year': '1971', 'stars': set()},
#  '65596': {'title': 'Cry Blood, Apache', 'year': '1970', 'stars': set()},
#  '65597': {'title': 'Cry of the Banshee', 'year': '1970', 'stars': set()},
#  '65598': {'title': 'Chronicle of a Lady', 'year': '1971', 'stars': set()},
#  '65599': {'title': 'Csak egy telefon', 'year': '1970', 'stars': set()},
#  '65600': {'title': 'Four Murders Are Enough, Darling',
#   'year': '1971',
#   'stars': set()},
#  '65601': {'title': 'Cuadrilátero', 'year': '1970', 'stars': set()},
#  '65607': {'title': 'Devilish Honeymoon', 'year': '1970', 'stars': set()},
#  '65610': {'title': 'Darker Than Amber', 'year': '1970', 'stars': set()},
#  '65611': {'title': 'Darling Lili', 'year': '1970', 'stars': set()},
#  '65612': {'title': 'Darpan', 'year': '1970', 'stars': set()},
#  '65613': {'title': 'Das haut den stärksten Zwilling um',
#   'year': '1971',
#   'stars': set()},
#  '65614': {'title': "That Can't Shake Our Willi!",
#   'year': '1970',
#   'stars': set()},
#  '65616': {'title': 'A Day at the Beach', 'year': '1970', 'stars': set()},
#  '65617': {'title': 'De profesión, sus labores',
#   'year': '1970',
#   'stars': set()},
#  '65618': {'title': 'Dead of Summer', 'year': '1970', 'stars': set()},
#  '65619': {'title': 'Deadline', 'year': '1971', 'stars': set()},
#  '65620': {'title': 'Deadlock', 'year': '1970', 'stars': set()},
#  '65621': {'title': 'The Conjugal Debt', 'year': '1970', 'stars': set()},
#  '65622': {'title': 'The Decameron', 'year': '1971', 'stars': set()},
#  '65623': {'title': 'La decente', 'year': '1971', 'stars': set()},
#  '65626': {'title': 'Play It Cool', 'year': '1970', 'stars': set()},
#  '65627': {'title': 'El desastre de Annual', 'year': '1970', 'stars': set()},
#  '65628': {'title': 'Después de los nueve meses',
#   'year': '1970',
#   'stars': set()},
#  '65629': {'title': 'O Destino Marca a Hora', 'year': '1970', 'stars': set()},
#  '65630': {'title': 'El tunco Maclovio', 'year': '1970', 'stars': set()},
#  '65631': {'title': 'Of Gods and the Undead', 'year': '1970', 'stars': set()},
#  '65632': {'title': 'Deux femmes en or', 'year': '1970', 'stars': set()},
#  '65633': {'title': 'El diablo Cojuelo', 'year': '1971', 'stars': set()},
#  '65634': {'title': 'Lu yin ji qing sha an', 'year': '1970', 'stars': set()},
#  '65635': {'title': 'Le diamant nu', 'year': '1970', 'stars': set()},
#  '65636': {'title': 'Diary of a Mad Housewife',
#   'year': '1970',
#   'stars': set()},
#  '65637': {'title': 'Diegue-Bi', 'year': '1970', 'stars': set()},
#  '65638': {'title': 'Stagecoach of the Condemned',
#   'year': '1970',
#   'stars': set()},
#  '65639': {'title': 'El dinero tiene miedo', 'year': '1970', 'stars': set()},
#  '65640': {'title': 'Il dio serpente', 'year': '1970', 'stars': set()},
#  '65641': {'title': "Dionysus in '69", 'year': '1970', 'stars': set()},
#  '65642': {'title': 'Dirty Dingus Magee', 'year': '1970', 'stars': set()},
#  '65643': {'title': 'The Dirty Mind of Young Sally',
#   'year': '1973',
#   'stars': set()},
#  '65644': {'title': "Disperatamente l'estate scorsa",
#   'year': '1970',
#   'stars': set()},
#  '65646': {'title': 'Django Defies Sartana', 'year': '1970', 'stars': set()},
#  '65648': {'title': 'Doctor in Trouble', 'year': '1970', 'stars': set()},
#  '65649': {'title': "Dodes'ka-den", 'year': '1970', 'stars': set()},
#  '65651': {'title': 'Bed & Board', 'year': '1970', 'stars': set()},
#  '65652': {'title': 'Don Erre que erre', 'year': '1970', 'stars': set()},
#  '65653': {'title': 'Don Giovanni', 'year': '1970', 'stars': set()},
#  '65655': {'title': "Don't Look for Me at Places Where I Can't Be Found",
#   'year': '1970',
#   'stars': set()},
#  '65656': {'title': 'Dorian Gray', 'year': '1970', 'stars': set()},
#  '65658': {'title': 'Dr. Imbedebilius', 'year': '1970', 'stars': set()},
#  '65659': {'title': 'Medical Doctor Sommer the Second',
#   'year': '1970',
#   'stars': set()},
#  '65660': {'title': 'Dracula, Prisoner of Frankenstein',
#   'year': '1972',
#   'stars': set()},
#  '65661': {'title': 'Dear Irena', 'year': '1970', 'stars': set()},
#  '65662': {'title': 'The Pizza Triangle', 'year': '1970', 'stars': set()},
#  '65663': {'title': 'The Dreamer', 'year': '1970', 'stars': set()},
#  '65666': {'title': 'Druzba Pere Kvrzice', 'year': '1970', 'stars': set()},
#  '65669': {'title': 'The Dunwich Horror', 'year': '1970', 'stars': set()},
#  '65670': {'title': 'Twelve Chairs', 'year': '1971', 'stars': set()},
#  '65671': {'title': 'Dyadya Vanya', 'year': '1971', 'stars': set()},
#  '65672': {'title': 'Dzieciol', 'year': '1971', 'stars': set()},
#  '65673': {'title': 'Dzien oczyszczenia', 'year': '1970', 'stars': set()},
#  '65674': {'title': 'Dziura w ziemi', 'year': '1970', 'stars': set()},
#  '65675': {'title': "Take Me, I'm Old Enough", 'year': '1970', 'stars': set()},
#  '65677': {'title': 'The Forbidden Photos of a Lady Above Suspicion',
#   'year': '1970',
#   'stars': set()},
#  '65678': {'title': 'Días de ceniza', 'year': '1970', 'stars': set()},
#  '65679': {'title': 'Los días duros', 'year': '1970', 'stars': set()},
#  '65681': {'title': 'Black Lemons', 'year': '1970', 'stars': set()},
#  '65683': {'title': 'Edipeon', 'year': '1970', 'stars': set()},
#  '65685': {'title': "Eliza's Horoscope", 'year': '1975', 'stars': set()},
#  '65686': {'title': 'Elle boit pas, elle fume pas, elle drague pas, mais... elle cause!',
#   'year': '1970',
#   'stars': set()},
#  '65687': {'title': "Elvis: That's the Way It Is",
#   'year': '1970',
#   'stars': set()},
#  '65688': {'title': 'Zapata', 'year': '1970', 'stars': set()},
#  '65690': {'title': 'En un lugar de La Manga', 'year': '1970', 'stars': set()},
#  '65691': {'title': 'Juan y Junior... en un mundo diferente',
#   'year': '1970',
#   'stars': set()},
#  '65692': {'title': 'End of the Road', 'year': '1970', 'stars': set()},
#  '65693': {'title': 'In the Folds of the Flesh',
#   'year': '1970',
#   'stars': set()},
#  '65696': {'title': 'Les enfants de Caïn', 'year': '1970', 'stars': set()},
#  '65698': {'title': 'Angels with Burnt Wings', 'year': '1970', 'stars': set()},
#  '65699': {'title': 'Enseñar a un sinvergüenza',
#   'year': '1970',
#   'stars': set()},
#  '65700': {'title': 'Entertaining Mr Sloane', 'year': '1970', 'stars': set()},
#  '65701': {'title': "Erika's Hot Summer", 'year': '1971', 'stars': set()},
#  '65702': {'title': 'Chariots of the Gods', 'year': '1970', 'stars': set()},
#  '65703': {'title': 'First Love', 'year': '1970', 'stars': set()},
#  '65704': {'title': 'Españolas en París', 'year': '1971', 'stars': set()},
#  '65705': {'title': 'Espérame en Siberia, vida mía',
#   'year': '1971',
#   'stars': set()},
#  '65709': {'title': 'Every Home Should Have One',
#   'year': '1970',
#   'stars': set()},
#  '65711': {'title': 'The Executioner', 'year': '1970', 'stars': set()},
#  '65712': {'title': 'Los extremeños se tocan', 'year': '1970', 'stars': set()},
#  '65713': {'title': 'Ezo yakata no ketto', 'year': '1970', 'stars': set()},
#  '65715': {'title': 'The Demise of Father Mouret',
#   'year': '1970',
#   'stars': set()},
#  '65716': {'title': 'Fe, esperanza y caridad', 'year': '1974', 'stars': set()},
#  '65717': {'title': 'Panafrican Festival', 'year': '1970', 'stars': set()},
#  '65718': {'title': 'Die Feuerzangenbowle', 'year': '1970', 'stars': set()},
#  '65719': {'title': 'Fiebre', 'year': '1971', 'stars': set()},
#  '65720': {'title': 'Figures in a Landscape', 'year': '1970', 'stars': set()},
#  '65722': {'title': 'The Firechasers', 'year': '1971', 'stars': set()},
#  '65724': {'title': 'Five Easy Pieces', 'year': '1970', 'stars': set()},
#  '65726': {'title': 'Flap', 'year': '1970', 'stars': set()},
#  '65727': {'title': 'Flesh Feast', 'year': '1970', 'stars': set()},
#  '65729': {'title': 'Fei jian shen tong', 'year': '1970', 'stars': set()},
#  '65731': {'title': 'Fools', 'year': '1970', 'stars': set()},
#  '65732': {'title': "Formula 1: Nell'Inferno del Grand Prix",
#   'year': '1970',
#   'stars': set()},
#  '65735': {'title': "Devil's Ransom", 'year': '1970', 'stars': set()},
#  '65736': {'title': 'The Madman', 'year': '1970', 'stars': set()},
#  '65737': {'title': 'Fragment of Fear', 'year': '1970', 'stars': set()},
#  '65739': {'title': 'The Hostess Also Likes to Blow the Horn',
#   'year': '1970',
#   'stars': set()},
#  '65740': {'title': 'The Hostess Exceeds All Bounds',
#   'year': '1970',
#   'stars': set()},
#  '65742': {'title': 'Fray Dólar', 'year': '1970', 'stars': set()},
#  '65743': {'title': 'Frisch, fromm, fröhlich, frei',
#   'year': '1970',
#   'stars': set()},
#  '65744': {'title': 'The Shiver of the Vampires',
#   'year': '1971',
#   'stars': set()},
#  '65748': {'title': 'Fuenteovejuna', 'year': '1972', 'stars': set()},
#  '65749': {'title': 'Slaughter on the Khyber Pass',
#   'year': '1970',
#   'stars': set()},
#  '65750': {'title': 'Fury of the Wolfman', 'year': '1972', 'stars': set()},
#  '65753': {'title': 'Fußball wie noch nie', 'year': '1971', 'stars': set()},
#  '65754': {'title': 'Fútbol México 70', 'year': '1970', 'stars': set()},
#  '65755': {'title': 'Gamera vs. Monster X', 'year': '1970', 'stars': set()},
#  '65756': {'title': 'Lady Chatterly Versus Fanny Hill',
#   'year': '1971',
#   'stars': set()},
#  '65757': {'title': 'The Games', 'year': '1970', 'stars': set()},
#  '65758': {'title': 'Ganwaar', 'year': '1970', 'stars': set()},
#  '65760': {'title': 'Gas! -Or- It Became Necessary to Destroy the World in Order to Save It.',
#   'year': '1970',
#   'stars': set()},
#  '65761': {'title': "The Cat o' Nine Tails", 'year': '1971', 'stars': set()},
#  '65762': {'title': 'Gebissen wird nur nachts - das Happening der Vampire',
#   'year': '1971',
#   'stars': set()},
#  '65764': {'title': 'Geet', 'year': '1970', 'stars': set()},
#  '65766': {'title': 'Keine Angst Liebling, ich pass schon auf',
#   'year': '1970',
#   'stars': set()},
#  '65767': {'title': 'The Militarists', 'year': '1970', 'stars': set()},
#  '65768': {'title': 'The Yellow House on Pinnasberg',
#   'year': '1970',
#   'stars': set()},
#  '65769': {'title': 'The Troops on Vacation', 'year': '1970', 'stars': set()},
#  '65770': {'title': 'La generala', 'year': '1971', 'stars': set()},
#  '65771': {'title': 'Genesis III', 'year': '1970', 'stars': set()},
#  '65772': {'title': "Claire's Knee", 'year': '1970', 'stars': set()},
#  '65773': {'title': 'Geschichten vom Kübelkind',
#   'year': '1971',
#   'stars': set()},
#  '65774': {'title': 'Gestatten... Vögelein im Dienst',
#   'year': '1971',
#   'stars': set()},
#  '65775': {'title': 'Getting Straight', 'year': '1970', 'stars': set()},
#  '65776': {'title': 'Space Amoeba', 'year': '1970', 'stars': set()},
#  '65777': {'title': 'The Garden of the Finzi-Continis',
#   'year': '1970',
#   'stars': set()},
#  '65780': {'title': 'Gimme Shelter', 'year': '1970', 'stars': set()},
#  '65782': {'title': 'Sunflower', 'year': '1970', 'stars': set()},
#  '65783': {'title': 'Give God a Chance on Sunday',
#   'year': '1970',
#   'stars': set()},
#  '65784': {'title': 'Down with Your Hands... You Scum!',
#   'year': '1971',
#   'stars': set()},
#  '65785': {'title': 'Das Glöcklein unterm Himmelbett',
#   'year': '1970',
#   'stars': set()},
#  '65787': {'title': 'Godard in America', 'year': '1970', 'stars': set()},
#  '65788': {'title': "Goin' Down the Road", 'year': '1970', 'stars': set()},
#  '65790': {'title': 'Goodbye Gemini', 'year': '1970', 'stars': set()},
#  '65792': {'title': 'Goya, historia de una soledad',
#   'year': '1971',
#   'stars': set()},
#  '65795': {'title': 'The Grasshopper', 'year': '1970', 'stars': set()},
#  '65797': {'title': 'The Great White Hope', 'year': '1970', 'stars': set()},
#  '65799': {'title': 'Pig Hunt', 'year': '1970', 'stars': set()},
#  '65801': {'title': 'The Big Mess', 'year': '1971', 'stars': set()},
#  '65802': {'title': 'Guess What We Learned in School Today?',
#   'year': '1970',
#   'stars': set()},
#  '65803': {'title': 'The Angry River', 'year': '1971', 'stars': set()},
#  '65804': {'title': 'Gold for the Tough Guys of the Prairie',
#   'year': '1971',
#   'stars': set()},
#  '65806': {'title': 'A gyilkos a házban van', 'year': '1971', 'stars': set()},
#  '65807': {'title': 'Gyula vitéz télen-nyáron',
#   'year': '1970',
#   'stars': set()},
#  '65808': {'title': 'Gods of the Plague', 'year': '1970', 'stars': set()},
#  '65809': {'title': 'Live Today, Die Tomorrow!',
#   'year': '1970',
#   'stars': set()},
#  '65810': {'title': 'Halls of Anger', 'year': '1970', 'stars': set()},
#  '65813': {'title': 'Hangyaku no Melody', 'year': '1970', 'stars': set()},
#  '65814': {'title': 'Happy Time', 'year': '1970', 'stars': set()},
#  '65815': {'title': 'The Hard Ride', 'year': '1971', 'stars': set()},
#  '65817': {'title': 'Hassan, the Bald', 'year': '1970', 'stars': set()},
#  '65818': {'title': 'Hatholdas rózsakert', 'year': '1970', 'stars': set()},
#  '65820': {'title': 'The Hawaiians', 'year': '1970', 'stars': set()},
#  '65823': {'title': 'Heintje - Mein bester Freund',
#   'year': '1970',
#   'stars': set()},
#  '65825': {'title': 'Hell Boats', 'year': '1970', 'stars': set()},
#  '65826': {'title': "Hell's Bloody Devils", 'year': '1970', 'stars': set()},
#  '65827': {'title': 'Hello Jim', 'year': '1970', 'stars': set()},
#  '65828': {'title': 'Hello-Goodbye', 'year': '1970', 'stars': set()},
#  '65829': {'title': 'Hembra', 'year': '1970', 'stars': set()},
#  '65830': {'title': 'Langlois', 'year': '1970', 'stars': set()},
#  '65831': {'title': 'A Herança', 'year': '1970', 'stars': set()},
#  '65832': {'title': 'Hercules in New York', 'year': '1970', 'stars': set()},
#  '65833': {'title': 'La hermanita Dinamita', 'year': '1970', 'stars': set()},
#  '65834': {'title': 'Heroic Purgatory', 'year': '1970', 'stars': set()},
#  '65835': {'title': 'Gentlemen in White Vests',
#   'year': '1970',
#   'stars': set()},
#  '65836': {'title': 'Hi, Mom!', 'year': '1970', 'stars': set()},
#  '65838': {'title': 'Hoa Binh', 'year': '1970', 'stars': set()},
#  '65839': {'title': 'Hoffman', 'year': '1970', 'stars': set()},
#  '65841': {'title': 'Hollywood Blue', 'year': '1970', 'stars': set()},
#  '65842': {'title': 'Mr. Superinvisible', 'year': '1970', 'stars': set()},
#  '65843': {'title': 'The Man in Hiding', 'year': '1971', 'stars': set()},
#  '65844': {'title': 'El hombre que se quiso matar',
#   'year': '1970',
#   'stars': set()},
#  '65845': {'title': 'El hombre que vino del odio',
#   'year': '1971',
#   'stars': set()},
#  '65846': {'title': 'Los hombres las prefieren viudas',
#   'year': '1970',
#   'stars': set()},
#  '65847': {'title': 'Homer', 'year': '1970', 'stars': set()},
#  '65848': {'title': 'The Band', 'year': '1970', 'stars': set()},
#  '65850': {'title': "Hornets' Nest", 'year': '1970', 'stars': set()},
#  '65851': {'title': 'The Horror of Frankenstein',
#   'year': '1970',
#   'stars': set()},
#  '65852': {'title': 'Horror of the Blood Monsters',
#   'year': '1970',
#   'stars': set()},
#  '65854': {'title': 'The House That Dripped Blood',
#   'year': '1971',
#   'stars': set()},
#  '65856': {'title': 'House of Dark Shadows', 'year': '1970', 'stars': set()},
#  '65859': {'title': 'How Do I Love Thee?', 'year': '1970', 'stars': set()},
#  '65861': {'title': 'The Fed One', 'year': '1970', 'stars': set()},
# ...
#  '66093': {'title': 'Monte Walsh', 'year': '1970', 'stars': set()},
#  '66094': {'title': 'El monumento', 'year': '1970', 'stars': set()},
#  '66095': {'title': 'Moonfire', 'year': '1970', 'stars': set()},
#  '66096': {'title': 'The Moonshine War', 'year': '1970', 'stars': set()},
#  '66098': {'title': 'Death Occurred Last Night',
#   'year': '1970',
#   'stars': set()},
#  '66099': {'title': 'Up Your Teddy Bear', 'year': '1970', 'stars': set()},
#  '66101': {'title': "Mourir d'aimer...", 'year': '1971', 'stars': set()},
#  '66102': {'title': 'Move', 'year': '1970', 'stars': set()},
#  '66104': {'title': 'She Killed in Ecstasy', 'year': '1971', 'stars': set()},
#  '66106': {'title': 'La mujer celosa', 'year': '1970', 'stars': set()},
#  '66108': {'title': 'Atlantic Wall', 'year': '1970', 'stars': set()},
#  '66109': {'title': 'The Music Lovers', 'year': '1971', 'stars': set()},
#  '66110': {'title': 'Musik, Musik - da wackelt die Penne',
#   'year': '1970',
#   'stars': set()},
#  '66111': {'title': 'Muz, ktery rozdaval smich',
#   'year': '1971',
#   'stars': set()},
#  '66112': {'title': 'Mwana keba', 'year': '1970', 'stars': set()},
#  '66113': {'title': 'My Lover, My Son', 'year': '1970', 'stars': set()},
#  '66115': {'title': 'Myra Breckinridge', 'year': '1970', 'stars': set()},
#  '66116': {'title': 'The Brutes', 'year': '1970', 'stars': set()},
#  '66117': {'title': 'De många sängarna', 'year': '1970', 'stars': set()},
#  '66118': {'title': "Le mépris n'aura qu'un temps",
#   'year': '1970',
#   'stars': set()},
#  '66119': {'title': 'N.N. a halál angyala', 'year': '1970', 'stars': set()},
#  '66120': {'title': 'Na kolejích ceká vrah', 'year': '1970', 'stars': set()},
#  '66121': {'title': 'Na komete', 'year': '1970', 'stars': set()},
#  '66122': {'title': 'Deep End', 'year': '1970', 'stars': set()},
#  '66123': {'title': 'After My Last Move', 'year': '1972', 'stars': set()},
#  '66124': {'title': 'The Beginning', 'year': '1970', 'stars': set()},
#  '66125': {'title': 'Nachbarn sind zum Ärgern da',
#   'year': '1970',
#   'stars': set()},
#  '66126': {'title': 'The Losers', 'year': '1970', 'stars': set()},
#  '66128': {'title': 'Nana', 'year': '1970', 'stars': set()},
#  '66129': {'title': 'El nano: Niñera con bigotes',
#   'year': '1971',
#   'stars': set()},
#  '66130': {'title': 'Ned Kelly', 'year': '1970', 'stars': set()},
#  '66132': {'title': 'Web of the Spider', 'year': '1971', 'stars': set()},
#  '66134': {'title': 'Netzwerk', 'year': '1970', 'stars': set()},
#  '66135': {'title': 'Nevesta', 'year': '1970', 'stars': set()},
#  '66136': {'title': 'It Is Not the Homosexual Who Is Perverse, But the Society in Which He Lives',
#   'year': '1971',
#   'stars': set()},
#  '66137': {'title': 'Nicht fummeln, Liebling!',
#   'year': '1970',
#   'stars': set()},
#  '66141': {'title': 'The Night Visitor', 'year': '1971', 'stars': set()},
#  '66143': {'title': 'Night of the Bloody Transplant',
#   'year': '1970',
#   'stars': set()},
#  '66144': {'title': 'The Night of the Sorcerers',
#   'year': '1974',
#   'stars': set()},
#  '66145': {'title': 'Night of the Witches', 'year': '1970', 'stars': set()},
#  '66147': {'title': 'Nihon kyokaku-den: Nobori Ryu',
#   'year': '1970',
#   'stars': set()},
#  '66148': {'title': 'Brave Red Flower of the North',
#   'year': '1970',
#   'stars': set()},
#  '66151': {'title': 'Ninja Destroyer', 'year': '1986', 'stars': set()},
#  '66152': {'title': 'Ninì Tirabusciò, la donna che inventò la mossa',
#   'year': '1970',
#   'stars': set()},
#  '66153': {'title': 'History of Postwar Japan as Told by a Bar Hostess',
#   'year': '1970',
#   'stars': set()},
#  '66154': {'title': 'No Blade of Grass', 'year': '1970', 'stars': set()},
#  '66155': {'title': 'No Coração de Angola', 'year': '1970', 'stars': set()},
#  '66156': {'title': 'No Place to Hide', 'year': '1973', 'stars': set()},
#  '66157': {'title': 'No Substitute for Victory',
#   'year': '1970',
#   'stars': set()},
#  '66158': {'title': 'No desearás al vecino del quinto',
#   'year': '1970',
#   'stars': set()},
#  '66159': {'title': 'Noboriryu tekkahada', 'year': '1970', 'stars': set()},
#  '66160': {'title': 'The Werewolf Versus the Vampire Woman',
#   'year': '1971',
#   'stars': set()},
#  '66161': {'title': 'Repulsion to Dogs', 'year': '1970', 'stars': set()},
#  '66162': {'title': 'Norwood', 'year': '1970', 'stars': set()},
#  '66163': {'title': 'Notes Towards an African Orestes',
#   'year': '1970',
#   'stars': set()},
#  '66164': {'title': 'Les novices', 'year': '1970', 'stars': set()},
#  '66165': {'title': 'Nowy', 'year': '1970', 'stars': set()},
#  '66167': {'title': 'Light the Fuse... Sartana Is Coming',
#   'year': '1970',
#   'stars': set()},
#  '66168': {'title': 'The Key to Paradise', 'year': '1970', 'stars': set()},
#  '66169': {'title': 'O Happy Day', 'year': '1970', 'stars': set()},
#  '66171': {'title': 'O.K.', 'year': '1970', 'stars': set()},
#  '66172': {'title': 'OK Cleopatra', 'year': '1971', 'stars': set()},
#  '66174': {'title': 'Oddly Coupled', 'year': '1970', 'stars': set()},
#  '66175': {'title': 'Odin iz nas', 'year': '1971', 'stars': set()},
#  '66177': {'title': 'Slap in the Face', 'year': '1970', 'stars': set()},
#  '66181': {'title': 'On a Clear Day You Can See Forever',
#   'year': '1970',
#   'stars': set()},
#  '66182': {'title': 'Once in a Lifetime', 'year': '1970', 'stars': set()},
#  '66183': {'title': 'One More Time', 'year': '1970', 'stars': set()},
#  '66184': {'title': 'The Only Game in Town', 'year': '1970', 'stars': set()},
#  '66185': {'title': 'The Only Way', 'year': '1970', 'stars': set()},
#  '66187': {'title': 'La orilla', 'year': '1971', 'stars': set()},
#  '66188': {'title': "Chapaqua's Gold", 'year': '1970', 'stars': set()},
#  '66190': {'title': "Tora-san's Runaway", 'year': '1970', 'stars': set()},
#  '66191': {'title': 'La otra residencia', 'year': '1970', 'stars': set()},
#  '66192': {'title': 'Out 1: Spectre', 'year': '1972', 'stars': set()},
#  '66193': {'title': 'The Out of Towners', 'year': '1970', 'stars': set()},
#  '66195': {'title': 'The Owl and the Pussycat',
#   'year': '1970',
#   'stars': set()},
#  '66196': {'title': 'Ozu no mahôtsukai', 'year': '1970', 'stars': set()},
#  '66197': {'title': 'Paddy', 'year': '1970', 'stars': set()},
#  '66198': {'title': 'Peace Over the Fields', 'year': '1970', 'stars': set()},
#  '66199': {'title': 'Pájaro loco', 'year': '1971', 'stars': set()},
#  '66201': {'title': 'Para servir a usted', 'year': '1971', 'stars': set()},
#  '66202': {'title': 'Paragon, gola!', 'year': '1970', 'stars': set()},
#  '66203': {'title': 'Paraíso amazónico', 'year': '1970', 'stars': set()},
#  '66204': {'title': 'Part One: 806', 'year': '1970', 'stars': set()},
#  '66206': {'title': 'Patton', 'year': '1970', 'stars': set()},
#  '66207': {'title': 'Donkey Skin', 'year': '1970', 'stars': set()},
#  '66208': {'title': 'Penicka a Paraplícko', 'year': '1971', 'stars': set()},
#  '66209': {'title': 'The People Next Door', 'year': '1970', 'stars': set()},
#  '66210': {'title': 'Coffin Full of Dollars', 'year': '1971', 'stars': set()},
#  '66211': {'title': 'Perestupi porog', 'year': '1970', 'stars': set()},
#  '66212': {'title': 'Perfect Friday', 'year': '1970', 'stars': set()},
#  '66214': {'title': 'Performance', 'year': '1970', 'stars': set()},
#  '66215': {'title': 'Fuck Off! Images of Finland',
#   'year': '1971',
#   'stars': set()},
#  '66216': {'title': 'Permissive', 'year': '1970', 'stars': set()},
#  '66217': {'title': "The Granddaughter's Model",
#   'year': '1971',
#   'stars': set()},
#  '66218': {'title': 'Early Morning', 'year': '1971', 'stars': set()},
#  '66219': {'title': 'Der Pfarrer von St. Pauli',
#   'year': '1970',
#   'stars': set()},
#  '66221': {'title': 'The Phynx', 'year': '1970', 'stars': set()},
#  '66222': {'title': 'Pieces of Dreams', 'year': '1970', 'stars': set()},
#  '66223': {'title': 'Pierna creciente, falda menguante',
#   'year': '1970',
#   'stars': set()},
#  '66224': {'title': 'Las piernas de la serpiente',
#   'year': '1970',
#   'stars': set()},
#  '66225': {'title': 'Castle of Pot', 'year': '1970', 'stars': set()},
#  '66226': {'title': 'Pim, Pam und Pummelchen', 'year': '1970', 'stars': set()},
#  '66227': {'title': 'Pippi in the South Seas', 'year': '1970', 'stars': set()},
#  '66228': {'title': 'Los corsarios', 'year': '1971', 'stars': set()},
#  '66229': {'title': 'Le pistonné', 'year': '1970', 'stars': set()},
#  '66230': {'title': 'Bullets Over Dallas', 'year': '1970', 'stars': set()},
#  '66231': {'title': 'Pogon za Adamem', 'year': '1970', 'stars': set()},
#  '66233': {'title': 'The Postman', 'year': '1972', 'stars': set()},
#  '66234': {'title': 'Pound', 'year': '1970', 'stars': set()},
#  '66236': {'title': 'Praise Marx and Pass the Ammunition',
#   'year': '1970',
#   'stars': set()},
#  '66237': {'title': 'The Adversary', 'year': '1970', 'stars': set()},
#  '66238': {'title': 'Pravda', 'year': '1970', 'stars': set()},
#  '66239': {'title': 'Prawdzie w oczy', 'year': '1970', 'stars': set()},
#  '66240': {'title': 'Shoot the Living and Pray for the Dead',
#   'year': '1971',
#   'stars': set()},
#  '66241': {'title': 'Prem Pujari', 'year': '1970', 'stars': set()},
#  '66242': {'title': 'Presage', 'year': '1970', 'stars': set()},
#  '66243': {'title': 'Il presidente del Borgorosso Football Club',
#   'year': '1970',
#   'stars': set()},
#  '66245': {'title': 'Priklyucheniya zhyoltogo chemodanchika',
#   'year': '1970',
#   'stars': set()},
#  '66248': {'title': 'Le printemps', 'year': '1970', 'stars': set()},
#  '66249': {'title': 'The Private Life of Sherlock Holmes',
#   'year': '1970',
#   'stars': set()},
#  '66250': {'title': 'Prom', 'year': '1970', 'stars': set()},
#  '66251': {'title': 'Promise at Dawn', 'year': '1970', 'stars': set()},
#  '66252': {'title': 'A Prostitute Serving the Public and in Compliance with the Laws of the State',
#   'year': '1971',
#   'stars': set()},
#  '66253': {'title': 'Heute', 'year': '1970', 'stars': set()},
#  '66256': {'title': 'Pufnstuf', 'year': '1970', 'stars': set()},
#  '66258': {'title': 'Puppet on a Chain', 'year': '1971', 'stars': set()},
#  '66259': {'title': 'Puruliar Chhou Nritya', 'year': '1970', 'stars': set()},
#  '66260': {'title': 'Pussycat, Pussycat, I Love You',
#   'year': '1970',
#   'stars': set()},
#  '66262': {'title': 'Puzzle of a Downfall Child',
#   'year': '1970',
#   'stars': set()},
#  '66263': {'title': 'Puzzlespiele', 'year': '1970', 'stars': set()},
#  '66265': {'title': 'Pippi on the Run', 'year': '1970', 'stars': set()},
#  '66266': {'title': 'Quackser Fortune Has a Cousin in the Bronx',
#   'year': '1970',
#   'stars': set()},
#  '66267': {'title': 'Something Creeping in the Dark',
#   'year': '1971',
#   'stars': set()},
#  '66268': {'title': 'When Women Had Tails', 'year': '1970', 'stars': set()},
#  '66271': {'title': 'Quelli belli... siamo noi',
#   'year': '1970',
#   'stars': set()},
#  '66272': {'title': 'Quizá siempre si me muera',
#   'year': '1970',
#   'stars': set()},
#  '66273': {'title': 'R.P.M.', 'year': '1970', 'stars': set()},
#  '66274': {'title': 'Rabbit, Run', 'year': '1970', 'stars': set()},
#  '66276': {'title': 'La ragazza di latta', 'year': '1970', 'stars': set()},
#  '66277': {'title': 'A Girl Called Jules', 'year': '1970', 'stars': set()},
#  '66279': {'title': 'The Railway Children', 'year': '1970', 'stars': set()},
#  '66282': {'title': 'Raj na ziemi', 'year': '1970', 'stars': set()},
#  '66283': {'title': 'The Rangers', 'year': '1970', 'stars': set()},
#  '66284': {'title': 'Rasplata', 'year': '1970', 'stars': set()},
#  '66285': {'title': 'The Ravager', 'year': '1970', 'stars': set()},
#  '66286': {'title': 'The Rebel Rousers', 'year': '1970', 'stars': set()},
#  '66287': {'title': 'Rebels of Arizona', 'year': '1970', 'stars': set()},
#  '66288': {'title': 'Red the Half Breed', 'year': '1970', 'stars': set()},
#  '66289': {'title': 'The Cruise', 'year': '1970', 'stars': set()},
#  '66290': {'title': 'El relicario', 'year': '1970', 'stars': set()},
#  '66291': {'title': 'Revolution My A..', 'year': '1970', 'stars': set()},
#  '66295': {'title': "Reverend's Colt", 'year': '1970', 'stars': set()},
#  '66296': {'title': 'The Revolutionary', 'year': '1970', 'stars': set()},
#  '66297': {'title': 'El rey de Acapulco', 'year': '1972', 'stars': set()},
#  '66299': {'title': 'The Right and the Wrong', 'year': '1970', 'stars': set()},
#  '66300': {'title': 'Right on!', 'year': '1970', 'stars': set()},
#  '66301': {'title': 'Rio Lobo', 'year': '1970', 'stars': set()},
#  '66302': {'title': 'The Rise and Rise of Michael Rimmer',
#   'year': '1970',
#   'stars': set()},
#  '66303': {'title': 'Risk', 'year': '1971', 'stars': set()},
#  '66307': {'title': 'Robin Hood: the Invincible Archer',
#   'year': '1970',
#   'stars': set()},
#  '66308': {'title': 'De Robins en de $100.000 schat',
#   'year': '1972',
#   'stars': set()},
#  '66309': {'title': 'Romantyczni', 'year': '1970', 'stars': set()},
#  '66310': {'title': 'Le revolver et la rose', 'year': '1970', 'stars': set()},
#  '66312': {'title': 'Rosolino Paternò, soldato...',
#   'year': '1970',
#   'stars': set()},
#  '66314': {'title': 'Der rote Reiter', 'year': '1970', 'stars': set()},
#  '66315': {'title': 'Roy Colt & Winchester Jack',
#   'year': '1970',
#   'stars': set()},
#  '66316': {'title': "Rubia's Jungle", 'year': '1970', 'stars': set()},
#  '66318': {'title': 'The Breach', 'year': '1970', 'stars': set()},
#  '66319': {'title': "Ryan's Daughter", 'year': '1970', 'stars': set()},
#  '66320': {'title': 'Rötmånad', 'year': '1970', 'stars': set()},
#  '66323': {'title': 'Sól ziemi czarnej', 'year': '1970', 'stars': set()},
#  '66324': {'title': 'Samskara', 'year': '1970', 'stars': set()},
#  '66325': {'title': 'San Domingo', 'year': '1970', 'stars': set()},
#  '66328': {'title': 'Santa and the Three Bears',
#   'year': '1970',
#   'stars': set()},
#  '66329': {'title': 'Santiago!', 'year': '1970', 'stars': set()},
#  '66331': {'title': 'Twenty Paces to Death', 'year': '1970', 'stars': set()},
#  '66333': {'title': 'Ballad of Death Valley', 'year': '1970', 'stars': set()},
#  '66334': {'title': 'Satiricosissimo', 'year': '1970', 'stars': set()},
#  '66335': {'title': 'The Savage Wild', 'year': '1970', 'stars': set()},
#  '66336': {'title': 'Say Goodbye', 'year': '1971', 'stars': set()},
#  '66337': {'title': 'Defeat of the Mafia', 'year': '1970', 'stars': set()},
#  '66338': {'title': 'Schaste Anny', 'year': '1971', 'stars': set()},
#  '66341': {'title': 'The School Girls', 'year': '1970', 'stars': set()},
#  '66344': {'title': 'Scrooge', 'year': '1970', 'stars': set()},
#  '66346': {'title': 'Finders Killers', 'year': '1971', 'stars': set()},
#  '66348': {'title': 'The Secret of the Sacred Forest',
#   'year': '1970',
#   'stars': set()},
#  '66349': {'title': 'Bizarre', 'year': '1970', 'stars': set()},
#  '66350': {'title': "You're Jinxed, Friend You've Met Sacramento",
#   'year': '1972',
#   'stars': set()},
#  '66351': {'title': 'Sem nevest efreytora Zbrueva',
#   'year': '1971',
#   'stars': set()},
#  '66354': {'title': 'Serdtse Rossii', 'year': '1970', 'stars': set()},
#  '66355': {'title': 'The Servant', 'year': '1970', 'stars': set()},
#  '66358': {'title': 'Sex-Power', 'year': '1970', 'stars': set()},
#  '66359': {'title': 'Sex Ritual of the Occult',
#   'year': '1970',
#   'stars': set()},
#  '66360': {'title': 'Sex and the Single Vampire',
#   'year': '1970',
#   'stars': set()},
#  '66361': {'title': 'Sex pervers', 'year': '1970', 'stars': set()},
#  '66362': {'title': 'Sex Jack', 'year': '1970', 'stars': set()},
#  '66363': {'title': 'Una señora llamada Andrés',
#   'year': '1970',
#   'stars': set()},
#  '66364': {'title': 'Shango', 'year': '1970', 'stars': set()},
#  '66366': {'title': 'Swordsman with an Umbrella',
#   'year': '1970',
#   'stars': set()},
#  '66368': {'title': 'Shin Abashiri Bangaichi: Dai Shinrin no Ketto',
#   'year': '1970',
#   'stars': set()},
#  '66369': {'title': 'Shin Abashiri Bangaichi: Fubuki no Hagure Okami',
#   'year': '1970',
#   'stars': set()},
#  '66370': {'title': "Tora-san's Grand Scheme", 'year': '1970', 'stars': set()},
#  '66371': {'title': 'Step on the Gas', 'year': '1970', 'stars': set()},
#  '66374': {'title': 'The Policeman', 'year': '1971', 'stars': set()},
#  '66375': {'title': 'Shôwa zankyô-den: Shinde moraimasu',
#   'year': '1970',
#   'stars': set()},
#  '66377': {'title': 'Si estás muerto, ¿por qué bailas?',
#   'year': '1971',
#   'stars': set()},
#  ...}
